# %% [markdown]
# <a href="https://colab.research.google.com/github/KK23100/KK2/blob/main/Untitled0.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ตัวแปรreward
rewardPoint = 0

#ทักทาย
print("Welcome to the caschier System")
#ราคา
price = int(input("price:" ))

#สมาชิก
Member = input("Member? (Enter Y/N)"": ")
#เงื่อนไข
if Member == "Y":
  print("Membership Discount : 10% off!")
  price = price * 0.9

  #เงื่อนไขคะแนนสะสม
  if price >= 100 and price < 1000:
    print("print above 500 : Receive 50 Reward Points")
    rewardPoint = rewardPoint + 50
  elif price >= 1000 and price < 5000:
    print("print above 1,000 : Receive 100 Reward Points")
    rewardPoint = rewardPoint + 100
  elif price >= 5000:
    print("print above 5000 : Receive 500 reward Points")
    rewardPoint = rewardPoint + 500
#วัน
print()
PurchasedDate = input("What is the day?"": ")

#เงื่อนไข
if PurchasedDate == "Saturday":
  print("Saturday Discount : 20% off!")
  price = price * 0.8

elif PurchasedDate == "Sunday":
  print("Sunday Discount : 40% off!")
  price = price * 0.6

#ลดประจำวัน
elif purchasedDate == "Monday" or purchasedDate == "Wednesday":
  print("Special Monday/Wednesday Promotion : 30% off!")
  price = price * 0.3

else :
  print("No promotion")

print()
print("Please Pay", price , "Baht")
print("Your reward Points is", rewardPoint)
# Out:
# Welcome to the caschier System
# price:100
# Member? (Enter Y/N): N
#
# What is the day?: Sunday
# Sunday Discount : 40% off!
#
# Please Pay 60.0 Baht
# Your reward Points is 0

# %%
rewardPoint = 0
itemCount = 0
totalPrice = 0

#ทักทาย
print("Welcome to the caschier System")

#รับข้อมูล
print()
numberOfItem = int(input("Number of items: "))
print()

#การทำซ้ำ
while itemCount < numberOfItem:
  price = int(input("Price:"))
  totalPrice = totalPrice + price
  itemCount = itemCount + 1

#สมาชิก
Member = input("Member? (Enter Y/N)"": ")
#เงื่อนไข
if Member == "Y":
  print("Membership Discount : 10% off!")
  totalPrice = totalPrice * 0.9

  #เงื่อนไขคะแนนสะสม
  if totalPrice >= 100 and totalPrice < 1000:
    print("print above 500 : Receive 50 Reward Points")
    rewardPoint = rewardPoint + 50
  elif totalPrice >= 1000 and totalPrice < 5000:
    print("print above 1,000 : Receive 100 Reward Points")
    rewardPoint = rewardPoint + 100
  elif totalPrice >= 5000:
    print("print above 5000 : Receive 500 reward Points")
    rewardPoint = rewardPoint + 500

#วัน
print()
PurchasedDate = input("What is the day?"": ")

#เงื่อนไข
if PurchasedDate == "Saturday":
  print("Saturday Discount : 20% off!")
  totalPrice = totalPrice * 0.8

elif PurchasedDate == "Sunday":
  print("Sunday Discount : 40% off!")
  totalPrice = totalPrice * 0.6

#ลดประจำวัน
elif purchasedDate == "Monday" or purchasedDate == "Wednesday":
  print("Special Monday/Wednesday Promotion : 30% off!")
  totalPrice = totalPrice * 0.3

else :
  print("No promotion")

print()
print("Please Pay", totalPrice , "Baht")
print("Your reward Points is", rewardPoint)

# %%
rewardPoint = 0
itemCount = 0
totalPrice = 0

#ทักทาย
print("Welcome to the caschier System")

#รับข้อมูล
print()
numberOfItem = int(input("Number of items: "))
print()

#การทำซ้ำ
while itemCount < numberOfItem:
  itemCount = itemCount + 1
  price = int(input("Price " + str(itemCount) + ": "))
  if itemCount == 5:
    print('special Promotion : Get 5th for free!!')
  else:
    totalPrice = totalPrice + price

#สมาชิก
print()
Member = input("Member? (Enter Y/N)"": ")
#เงื่อนไข
if Member == "Y":
  print("Membership Discount : 10% off!")
  totalPrice = totalPrice * 0.9

  #เงื่อนไขคะแนนสะสม
  if totalPrice >= 100 and totalPrice < 1000:
    print("print above 500 : Receive 50 Reward Points")
    rewardPoint = rewardPoint + 50
  elif totalPrice >= 1000 and totalPrice < 5000:
    print("print above 1,000 : Receive 100 Reward Points")
    rewardPoint = rewardPoint + 100
  elif totalPrice >= 5000:
    print("print above 5000 : Receive 500 reward Points")
    rewardPoint = rewardPoint + 500

#วัน
print()
PurchasedDate = input("What is the day?"": ")

#เงื่อนไข
if PurchasedDate == "Saturday":
  print("Saturday Discount : 20% off!")
  totalPrice = totalPrice * 0.8

elif PurchasedDate == "Sunday":
  print("Sunday Discount : 40% off!")
  totalPrice = totalPrice * 0.6

#ลดประจำวัน
elif purchasedDate == "Monday" or purchasedDate == "Wednesday":
  print("Special Monday/Wednesday Promotion : 30% off!")
  totalPrice = totalPrice * 0.3

else :
  print("No promotion")

print()
print("Please Pay", totalPrice , "Baht")
print("Your reward Points is", rewardPoint)
# Out:
# Welcome to the caschier System
#
# Number of items: 5
#
# Price 1: 2
# Price 2: 4
# Price 3: 6
# Price 4: 3
# Price 5: 200
# special Promotion : Get 5th for free!!
#
# Member? (Enter Y/N): Y
# Membership Discount : 10% off!
#
# What is the day?: Sunday
# Sunday Discount : 40% off!
#
# Please Pay 8.1 Baht
# Your reward Points is 0
